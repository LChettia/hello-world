# %%
import pandas as pd
import numpy as np
import datetime

# %%
df_intake = pd.read_csv('intake_data.csv', parse_dates=['intake_date'])
df_intake.head()
# Out:
#   intake_date  intake_count
# 0  2019-04-12             1
# 1  2019-08-28            17
# 2  2019-09-13             1
# 3  2019-09-17            15
# 4  2019-09-23            14

# %%
df_output = pd.read_csv('output_data.csv', parse_dates=['output_date'])
df_output.head()
# Out:
#   output_date  output_count
# 0  2019-10-04          3000
# 1  2019-10-07          3500
# 2  2019-10-08          3500
# 3  2019-10-09          3500
# 4  2019-10-10          3500

# %%
df_intake['balance'] = df_intake['intake_count']
df_output['balance'] = df_output['output_count']

# %%
prod_start_date = pd.datetime(2019, 10, 7)
prod_end_date = pd.datetime(2019, 10, 13)

# %%
pdr = pd.date_range(start=prod_start_date, end=prod_end_date)
pdr
# Out:
# DatetimeIndex(['2019-10-07', '2019-10-08', '2019-10-09', '2019-10-10',
#                '2019-10-11', '2019-10-12', '2019-10-13'],
#               dtype='datetime64[ns]', freq='D')

# %%
starting_wip = df_intake[df_intake['intake_date'] <= prod_start_date]['balance'].sum()

# %%
starting_wip
# Out:
# 3714

# %%
output_profile = {0: 0, 1: 6200}

# %%
data = pd.read_excel('SC Projections.xlsx', sheet_name='inventory', parse_dates=['start_date', 'service_request_date', 'intersite_received_date', 'intake_date'])

# %%
data
# Out:
#    start_date service_request_date intersite_received_date intake_date  \
# 0  2019-10-09           2019-10-07              2019-10-09  2019-10-04
# 1  2019-10-08           2019-10-08                     NaT  2019-10-08
# 2  2019-10-09           2019-10-09                     NaT  2019-10-09
# 3  2019-10-09           2019-10-09                     NaT  2019-10-08
# 4  2019-10-10           2019-10-10                     NaT  2019-10-10
# 5  2019-10-11           2019-10-11                     NaT  2019-10-11
# 6  2019-10-09           2019-10-09                     NaT  2019-10-09
# 7  2019-10-08           2019-10-08                     NaT  2019-10-08
# 8  2019-10-09           2019-10-09                     NaT  2019-10-08
# 9  2019-10-11           2019-10-11                     NaT  2019-10-11
# 10 2019-10-11           2019-10-11                     NaT  2019-10-11
#
#    service_id location_id  stone_count  service_priority  location_priority
# ...

# %%
data['rnk'] = data[['start_date','service_request_date', 'intake_date', 'service_priority','location_priority']].apply(tuple, axis=1).rank(method='dense', ascending=True)

# %%
data
# Out:
#    start_date service_request_date intersite_received_date intake_date  \
# 0  2019-10-09           2019-10-07              2019-10-09  2019-10-04
# 1  2019-10-08           2019-10-08                     NaT  2019-10-08
# 2  2019-10-09           2019-10-09                     NaT  2019-10-09
# 3  2019-10-09           2019-10-09                     NaT  2019-10-08
# 4  2019-10-10           2019-10-10                     NaT  2019-10-10
# 5  2019-10-11           2019-10-11                     NaT  2019-10-11
# 6  2019-10-09           2019-10-09                     NaT  2019-10-09
# 7  2019-10-08           2019-10-08                     NaT  2019-10-08
# 8  2019-10-09           2019-10-09                     NaT  2019-10-08
# 9  2019-10-11           2019-10-11                     NaT  2019-10-11
# 10 2019-10-11           2019-10-11                     NaT  2019-10-11
#
#    service_id location_id  stone_count  service_priority  location_priority  \
# ...

# %%
pd.merge(data, location_priority, ser_priority)
# Out:
# ---------------------------------------------------------------------------
# MergeError                                Traceback (most recent call last)
# <ipython-input-176-65e5228f2bdf> in <module>
# ----> 1 pd.merge(location_priority, ser_priority, data)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      45                          right_index=right_index, sort=sort, suffixes=suffixes,
#      46                          copy=copy, indicator=indicator,
# ---> 47                          validate=validate)
#      48     return op.get_result()
#      49
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     522             warnings.warn(msg, UserWarning)
# ...

# %%
location_priority
# Out:
#   location_id  location_priority
# 0          CB                  1
# 1          NY                  2
# 2          MB                  3

# %%
ser_priority
# Out:
#   service_id  service_priority
# 0         DD                 2
# 1         DG                 1
